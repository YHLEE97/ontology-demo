# %%
import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import OpenAIEmbeddings

# 순수 OpenAI 임베딩 모델 초기화
embeddings = OpenAIEmbeddings(
    api_key=os.environ.get("OPENAI_API_KEY"),
    model=os.environ.get("OPENAI_EMBEDDING_MODEL", "text-embedding-3-small"),
)

test_text = "OpenAI Embedding 연동 테스트"
print(f"[System] 입력 텍스트: '{test_text}'")
print("[System] 임베딩 벡터 변환 시작...")

# 텍스트를 벡터로 변환
vector = embeddings.embed_query(test_text)

print(f"[System] 임베딩 변환 완료. (차원 수: {len(vector)})")
print(f"[System] 벡터 데이터 일부: {vector[:5]} ...")
# Out:
# [System] 입력 텍스트: 'OpenAI Embedding 연동 테스트'
# [System] 임베딩 벡터 변환 시작...
# [System] 임베딩 변환 완료. (차원 수: 1536)
# [System] 벡터 데이터 일부: [-0.02337646484375, -0.03973388671875, 0.02764892578125, -0.0275115966796875, 0.0027256011962890625] ...
